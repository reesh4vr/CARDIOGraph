# %% [markdown]
# # Agentic Interface for CARDIOGraph
#
# This notebook demonstrates the LangChain-based agentic pipeline for querying the knowledge graph using natural language.

# %%
import sys
from pathlib import Path
from dotenv import load_dotenv
import os

# Add src to path
sys.path.append(str(Path('../src').resolve()))

from agent.agentic_pipeline import CardioGraphAgent

# Load environment variables
load_dotenv()

# Initialize agent
agent = CardioGraphAgent()
