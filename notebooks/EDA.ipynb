# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook explores the biomedical datasets used in CARDIOGraph:
# - DrugBank
# - DisGeNET
# - CTD
# - STRING
# - ChEMBL
# - FAERS
#
# We'll analyze data distributions, relationships, and identify patterns relevant to cardiotoxicity.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Data directories
raw_dir = Path('../data/raw')
processed_dir = Path('../data/processed')
